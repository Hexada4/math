# %%
from sympy import *
init_printing()

# %% [markdown]
# f(x)=$x^{2}$+3x-4, f'(x)=2x+3.

# %%
x = Symbol('x')
f = x**2 + 3*x - 4
f
# Out:
#  2
# x  + 3⋅x - 4

# %%
f_ = 2*x + 3 
solution = solve(f_)[0]
solution
# Out:
# -3/2

# %%
plot(f, (x, -1.5, 3))

# %% [markdown]
# f(x)=$x^{3}$-$2x^{2}$+x-6, f'(x)=$3x^{2}$-4x+1.

# %%
f = x**3 - 2*x**2 + x - 6
f
# Out:
#  3      2
# x  - 2⋅x  + x - 6

# %%
f_ = 3*x**2 - 4*x + 1
f_
# Out:
#    2
# 3⋅x  - 4⋅x + 1

# %%
solution = solve(f_)
solution
# Out:
# [1/3, 1]

# %%
plot(f, (x, -5, 1/3))

# %%
plot(f, (x, 1, 5))

# %% [markdown]
# f(x)=$e^{2x-x^{2}}$, f'(x)=(2-2x)$e^{2x-x^{2}}$.

# %%
f = E**(2*x - x**2)
f
# Out:
#     2
#  - x  + 2⋅x
# ℯ

# %%
f_ = (2 - 2*x) * E**(2*x - x**2)
solution = solve(f_)
solution
# Out:
# [1]

# %%
plot(f)
